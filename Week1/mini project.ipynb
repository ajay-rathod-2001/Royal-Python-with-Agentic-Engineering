# %% [markdown]
# ## Mini project :

# %%
a =1
print(a)

b = 2
print(b)

age =input("Enter ur age : ")
print("user age is : ", age)
c = 9
print(c)
# Out:
# 1
# 2
# user age is :
# 9

# %%
"royal".upper()
# Out:
# 'ROYAL'

# %%
"Royal".lstrip()
# Out:
# 'Royal'

# %%
first_name="RoYal"
last_name="PyThon"

print(first_name.title(), last_name.title())
# Out:
# Royal Python
