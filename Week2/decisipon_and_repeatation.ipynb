# %% [markdown]
# ## Decision And Repeatation:

# %% [markdown]
# ### if/elif/else and Truthiness:

# %% [markdown]
# ## 1) IF Concept:

# %%
is_raining = True

if is_raining:
	print("take a umbrella")
# Out:
# take a umbrella

# %% [markdown]
# ## 2) Truthiness:

# %%
name =input("Enter Your Name: ")

if name:
	print(f"hello, {name}")
else:
	print("Please Enter your name")
# Out:
# hello, Royal Python
